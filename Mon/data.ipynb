# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('C:\\Users\\hp\\Mondata\\NVIDIA_Stock_Volatility_2014_2024.csv')
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.head()
# Out:
#         Date     Close      High       Low      Open     Volume  Daily_Return  \
# 0 2014-01-31  0.370194  0.372316  0.365242  0.365478  335348000     -0.001272
# 1 2014-02-03  0.365242  0.373259  0.363827  0.372787  431728000     -0.013376
# 2 2014-02-04  0.367364  0.368071  0.363120  0.365006  280692000      0.005810
# 3 2014-02-05  0.364063  0.365949  0.361233  0.364770  214676000     -0.008986
# 4 2014-02-06  0.368779  0.369722  0.364063  0.364535  168380000      0.012953
#
#    Rolling_Volatility       ATR  Rolling_Mean  Upper_Band  Lower_Band
# 0            0.016288  0.007461      0.372964    0.385216    0.360713
# 1            0.016343  0.007293      0.372752    0.385398    0.360106
# 2            0.016091  0.006787      0.372398    0.385240    0.359557
# 3            0.015657  0.006838      0.371573    0.384325    0.358821
# 4            0.015622  0.006990      0.370724    0.381627    0.359821

# %%
# 1. Plot closing price and rolling mean
plt.figure(figsize=(12, 6))
plt.plot(df.index, df['Close'], label='Close Price', color='blue', alpha=0.7)
plt.plot(df.index, df['Rolling_Mean'], label="20 Day Rolling Mean", color='orange', linestyle='--')
plt.title('NVIDIA Stock Closing Price and 20-Day Rolling Mean (2014-2024)')
plt.xlabel('Date')
plt.ylabel('Price in USD')
plt.legend()
plt.grid(True)
plt.show()

# %%
# 2. Plot Rolling Volatility
plt.plot(df.index, df['Rolling_Volatility'], label='Rolling Volatility', color='red', alpha=0.7)
plt.title('NVIDIA Stock 20-Day Rolling Volatility (2014-2024)')
plt.xlabel('Date')
plt.ylabel('Volatility (Standard Deviation)')
plt.legend()
plt.grid(True)
plt.show()
